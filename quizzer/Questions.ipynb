# %% [markdown]
# doconce format pdflatex activity.do  --latex_code_style=pyg
#
# pdflatex -shell-escape activity

# %%
from quizz import register_ipython_magics
register_ipython_magics()

# %%
# %%activity ~/activity.do::04/27/2021 03:08PM::120
#
# !bquestion
# !bquiz
# Q: [] What solid angle is subtended at the center of a sphere by an area of $1.6 \,m^2$? The radius of the sphere is $5 \,m$ ?
# Cw: $0.1024 \,sr$
# Cw: $0.32 \,sr$
# Cr: $0.0640 \,sr$
# E: It is calculated as $\Omega = \frac{A}{R^2} \,sr$
# Cw: $0.1024 \,sr$
# Cw: $0.0640 \,sr$
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] A $400 \,cd$ light is located $2.4 \,m$ from a tabletop of area $1.2\, m^2$. What is the illumination and what flux F  falls on the table?
# Cr: $E = 69.4 \,lx \, and\, F = 93.3 \,lm$
# E: It is calculated as $E = \frac{I}{R^2} lx\, and \, F = EA \,lm$
# Cw: $E = 333.3 \,lx \, and\, F = 1919.808 \,lm$
# Cw: $E = 1919.808 \,lx \, and\, F = 333.3 \,lm$
# Cw: $E = 69.4 \,lx \, and\, F = 1919.808 \,lm$
# Cw: $E = 93.3 \,lx \, and\, F = 69.4 \,lm$
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] Calculate the required wattage for a LED lamp required to adequately illuminate a bedroom of size $20\times30\,square\,feet$. A typical value for a bedroom is 300 lux. Use tables below
# Cw: $3 \,watts$
# Cw: $32 \,watts$
# Cw: $10-16 \,watts$
# Cw: $5-8 \,watts$
# Cr: $24-30 \,watts$
# E: It is calculated as $F = EA \,lm$, then check F lumens on the table and select the corresponding LED wattage
# !equiz
# !equestion
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/watt_lumen.png, width=100 frac=0.8]
#
# !bquestion
# !bquiz
#
# Q: [] The ring magnet below is wound with 250 turns of wire through which a current of 1.5 A flows. Assume the relative permeability of the iron to be 800. Neglecting fringing, determine the flux in the ring and aslo the flux density. $l_1 = 45.7 \,cm, l_2 = 0.476 \,cm, A_1 = A_2 = 1.29 \,sq. cm$
# Cw: $\phi = 1,361 \,Wb, \, B = 1055 \,T$
# Cw: $\phi = 1,140 \,Wb, \, B = 884 \,T$
# Cr: $\phi = 907 \,Wb, \, B = 703 \,T$
# E: $$F = IN$$ *Notice that there is only one source F and 2 paths in series (the ring and air gap) for the flux generated, hence we have two reluctances:* $$\phi = \frac{F}{S} = \frac{F}{\frac{l_1}{A_1\mu_1} + \frac{l_2}{A_2\mu_2}}$$ Since the cross-sectional areas are the same, B will be equal on both paths $$B = \frac{\phi}{A}$$
# Cw: $\phi = 10.6 \,Wb, \, B = 8.2 \,T$
# Cw: $\phi = 0.0145 \,Wb, \, B = 0.011 \,T$
# !equiz
# !equestion
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/mag_cir_1.png, width=100 frac=0.8]
#
# !bquestion
# !bquiz
# Q: [] A  mild-steel  ring  having  a  cross-sectional  area  of  500 $mm^2$ and  a mean  circumference  of  400 mm  has  a  coil  of  200 turns  wound  uniformly around it. Calculate the current required to produce a flux of $800 \mu Wb$ in the ring. The following table gives the corresponding relative permeability to flux densities.
#
#
# |--c--------c-----|
# |B(T)  | $\mu_r$  |
# |---r-------r-----|
# | 1.6  | 380      |
# | 1.4  | 725      |
# | 1.2  | 2550     |
# |-----------------|
#
# Cw: $5.70\,A$
# Cw: $7.70\,A$
# Cw: $4.70\,A$
# Cw: $2.70\,A$
# Cr: $6.70\,A$
#
# E: A = 500 $mm^2$ = 5 $\times$ $10^{-4}$
# $l$ = 400 mm = 0.4 m
# N = 200 turns
# flux = $800\times10^{-6}\,Wb$
#
# (a)
#
# $$S = \frac{F}{\phi}$$
#
# $$B = \frac{\phi}{A}$$
#
# Use the B calculated to find $\mu_r$ from the table
#
# $$H = \frac{B}{\mu_0 \mu_r}$$
#
# $$F = Hl = \frac{Bl}{\mu_0 \mu_r} = \frac{\phi l}{\mu_0 \mu_r A}$$
#
# $$S = \frac{l}{\mu_0 \mu_r A}$$
#
# (b)
#
# $$I = \frac{F}{N}$$
#
#
# !equiz
# !equestion
#
#
# !bquestion
# !bquiz
# Q:[] The field core of a dynamo is $0.0762\,m$ long and $0.1016\,m$ in diameter. At $1.24\,T$ it has a permeability of 700. What is the reluctance between opposite ends of this field core at this flux density?
#
# Cw: $3401.10\,A/Wb$
# Cw: $2671.22\,A/Wb$
# Cr: $10684.88\,A/Wb$
# Cw: $0.0134\,A/Wb$
# Cw: $0.0034\,A/Wb$
#
# E: Diameter = $0.1016\,m$ $\therefore$ A = $\pi \frac{d}{2}^2\,m^2$
# $l$ = $0.0762\,m$
# $\mu$ = 700
# B = 1.24 T
#
# $$ S = \frac{F}{\phi} = \frac{Hl}{BA} = \frac{l}{A\mu_0\mu_r}$$
#
# !equiz
# !equestion
#
#
# !bquestion
# !bquiz
# Q: [] A playground of 10 meters x 45 meters size is to be illuminated by 10 lamps of 500 W each. The luminous efficiency of each lamp is 20 lumens/ watt. Allowing a depreciation factor of 0.70 and utilization of 0.40, determine the illumination on ground.
#
# Cw: $0.015\,lx$
# Cw: $0.0124\,lx$
# Cw: $75\,lx$
# Cr: $62.22\,lx$
# Cw: $150\,lx$
#
# E: $$ E = \frac{Df \times Uf \times Total\,lumens}{A} \, lx$$
#
#     Total lumens = luminous efficiency x wattage/lamp x 10
#
# !equiz
# !equestion
#
#
# !bquestion
# !bquiz
#
# Q: [] Which states the difference between watt and lumen?
#
# Cw: Watt measures energy use and brightness, and lumen the light brightness
# Cr: Watt measures energy use, and lumen the light output or brightness
# Cw: Watt measures the light output or brightness, and lumen measures energy use
# Cw: Watt measures the light output, and lumen measures energy use and brightness
# Cw: None of the above
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] A hall of area $400\, m^2$ is illuminated by 5 lamps of 500 Watts each. The luminous efficiency of each lamp is 10 lumens/ watt. Allowing a depreciation factor of 0.7 and coefficient of utilization of 0.5, determine the illumination on floor.
#
# Cw: $19.44\,lx$
# Cw: $0.2188\,lx$
# Cw: $0.0088\,lx$
# Cw: $87.5\,lx$
# Cr: $21.88\,lx$
#
# E: $$ E = \frac{Df \times Uf \times Total\,lumens}{A} \, lx$$
#
#     Total lumens = luminous efficiency x wattage/lamp x 10
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] The illumination in a drawing office 30 m x 10 m is to have a value of 250 lux and is to be provided by a number of 300 Watts filament lamps. If the coefficient of utilization is 0.4 and depreciation factor is 0.9, determine the number of lamps required. The luminous efficiency of each lamp is 14 lm/W.
#
# Cw: $70\,lamps$
# Cw: $60\,lamps$
# Cw: $45\,lamps$
# Cw: $40\,lamps$
# Cr: $50\,lamps$
#
# E: $$ F = \frac{E \times A}{Df \times Uf} \, lx$$
#
#     Number of lamps = F/lumen per lamp
#
# !equiz
# !equestion
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/zener.png, width=50 frac=0.4]
#
# !bquestion
# !bquiz
# Q: [] What are the functions of the zener diode and resistor in the circuit above?
#
# Cw: The zener diode is reverse biased and so the source voltage will appear across it while the resistor will limit the current flow
# Cw: The zener diode acts to rectify the load voltage while the resistor limits the forward current which varies almost linearly with the forward voltage
# Cw: The zener diode acts to rectify the load voltage while the resistor limits the reverse current which can vary over a wide range
# Cr: The zener diode acts to stabilize the load voltage while the resistor limits the reverse current which can vary over a wide range for a constant reverse voltage
# Cw: The zener diode acts to stabilize the load voltage while the resistor limits the forward current which varies almost linearly with the forward voltage
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] The four diodes used in a bridge rectifier circuit have forward resistances which may be considered negligible, and infinite reverse resistances. The alternating supply voltage is 230 V r.m.s. and the resistive load is 46.0 Ω. Calculate the mean load current;
#
# Cr: 4.5 A
# Cw: 7.07 A
# Cw: 2.25 A
# Cw: 4.999 A
# Cw: 3.535 A
#
# E: $$r_d = 0, \, r_i = \propto, \, V_{rms} = 230\,V, \, R_L = 46\,\Omega$$
#
# $$I_{dc} = \frac{2I_m}{\pi}$$
#
# $$V_{rms} \times\sqrt2 = V_{m} \, and \, I_m = \frac{V_m}{R_L}$$
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] The four diodes used in a bridge rectifier circuit have forward resistances which may be considered negligible, and infinite reverse resistances. The alternating supply voltage is 220 V r.m.s. and the resistive load is 55.0 Ω. Calculate the rectifier efficiency.
#
# Cw: 0.5732
# Cw: 0.4053
# Cw: 1.2732
# Cw: 2.5465
# Cr: 0.8105
#
# E: $$r_d = 0, \, r_i = \propto, \, V_{rms} = 230\,V, \, R_L = 46\,\Omega$$
#
# $$I_{dc} = \frac{2I_m}{\pi}$$
#
# $$I_{rms} = \frac{I_m}{\sqrt2}$$
#
# $$\eta = \frac{I_{dc}^2\,R_L}{I_{rms}^2\,R_L}$$
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] A full bridge rectifier circuit with an alternating supply voltage of 240 Vmax and the resistive load of 100.0 Ω, have diodes with forward resistances of 0.9 $\Omega$, and infinite reverse resistances. Calculate the value of the direct current supplied to the load.
#
# Cw: 1.53 A
# Cw: 2.16 A
# Cr: 1.50 A
# Cw: 2.12 A
# Cw: 1.08 A
#
# E:  $$I_m = \frac{V_m}{R_L + 2r_d}$$
#     $$I_{dc} = \frac{2I_m}{\pi}$$
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
#
# Q: [] A 230V, 0.5KW water heater is connected across a half-wave rectifier. What is the effective power delivered to the heater?
#
# Cw: 200 W
# Cw: 450 W
# Cr: 125 W
# Cw: 250 W
# Cw: 500 W
#
# E:  $$R = \frac{V^2}{P}$$
#     $$V_{rms} = \frac{V}{2}$$
#     $$P_{effective} = \frac{V_{rms}^2}{R}$$
#
# !equiz
# !equestion
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/diode1.png, width=100 frac=0.8]
#
# !bquestion
# !bquiz
#
# Q: [] For the circuit above, after the switch is closed the voltage across the load (shown open) remains constant. Assuming that all initial conditions are zero. The element across the load would be a/an
#
# Cw: resistor
# Cw: inductor
# Cr: capacitor
# Cw: None of the above
# Cw: data not sufficient
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
#
# Q: [] A magnetic circuit comprises three parts in series, each of uniform cross-sectional area (c.s.a.). They are:
#
# (a) a length of 100 mm and c.s.a. 60 $mm^2$,
#
# (b) a length of 70 mm and c.s.a. 80 $mm^2$,
#
# (c) an airgap of length 0.7 mm and c.s.a. 120 $mm^2$.
#
# A coil of 5000 turns is wound on part (b), and the flux density in the airgap is 0.50 T. Assuming that all the flux passes through the given circuit, and that the relative permeability $\mu_r$ is 1300, estimate the coil current to produce such a flux density.
#
# Cw: 46.3 mA
# Cw: 38.4 mA
# Cw: 45.4 mA
# Cr: 74.3 mA
# Cw: 55.7 mA
#
# E:
#
# * Since the circuit elements are in seires, same flux will pass through them all.
#
# * Air being non-magnetic, has the permeability of free space.
#
# * The total mmf in the series circuit is: $F_b$
#
# * The assumption here is that there is no leakage.
#
# $$\phi_{air} = \phi_{total} = B\times A $$
#
# $$\phi = \frac{F_b}{S_{total}} = \frac{F_b}{\frac{l_a}{A_a\mu_a} + \frac{l_b}{A_b\mu_b} + \frac{l_c}{A_c\mu_c}}$$
#
# $$F_b = IN$$
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
#
# Q: [] A coil of 5000 turns, wound on a core of non-magnetic material, has an inductance of 100 mH. Calculate the average value of the e.m.f. induced when a current of 10 A is reversed in 10 ms (milliseconds).
#
# Cw: 0.02 V
# Cw: 2 V
# Cw: 20 V
# Cr: 200 V
# Cw: 0.2 V
#
# E:
#
# $$e = L\times\frac{\bigtriangleup{I}}{\bigtriangleup{t}}$$
#
# !equiz
# !equestion
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/dc_curve.png, width=50 frac=0.4]
#
# !bquestion
# !bquiz
#
# Q: [] The curves in the graph above shows relationships between the magnetising current and flux. Curve OBD depicts the relationship in ferromagnetic circuit without airgap while OFG is a circuit with the same ferromagnetic material but with an airgap.
#     Which of the following best describes the differences between the two circuits?
#
# Cw: The introduction of airgap in curve OFG has the effect of increasing the inductance beyond what is obtainable in curve OBD
# Cw: The effective induced emf in curve OBD at saturation is more than that of OFG
# Cw: The rate of change of magnetising flux with current in curve OBD signifies a prolonged saturation than in curve OFG
# Cw: The curve OFG is definitely a suboptimal version of OBD so it is not very useful
# Cr: Flux-linkage per ampere at FG is higher than BD hence the introduction of airgap has prolonged the unset of saturation.
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] A coil having a resistance of 40 Ω and a constant inductance of 20 H is switched across a 50 V d.c. supply. Calculate the value of the current 1.0 s after the switch is closed.
#
# Cw: 1.6 mA
# Cr: 1.08 A
# Cw: 1.42 A
# Cw: 17 mA
# Cw: 0.49 A
#
# E:
#
# $$T = \frac{L}{R}$$
#
# $$I = \frac{V}{R}$$
#
# $$i = I(1-e^{-\frac{t}{T}})$$
#
# !equiz
# !equestion
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/gro_dec_cir.png, width=50 frac=0.4]
#
# !bquestion
# !bquiz
#
# Q: [] For the network shown above when the switch is closed on to position 2 at t = 100 ms from position 1 which it has been since t = 0, determine the expression for the inductor current.
#
# Cr: $1.33e^{(\frac{-t}{20\times10^{-3}})}$ A
# Cw: $2(1 - e^{(\frac{-t}{50\times10^{-3}})})$ A
# Cw: $0.8e^{(\frac{-t}{33\times10^{-3}})}$ A
# Cw: $2e^{(\frac{-t}{25\times10^{-3}})}$ A
# Cw: $1.33(1 - e^{(\frac{-t}{30\times10^{-3}})})$ A
#
# E:
#
# $$I = V/R$$
#
# $$T_1 = \frac{L}{R_1}$$
#
# At this time, $5\, \times \, T_1$ = 33 ms as passed, hence the circuit is in steady state; meaning the current has attained its final value $I$.
#
# This is a current decay scenerio
#
# $$R_T = R_1 + R_2$$
#
# $$T_2 = \frac{L}{R_T}$$
#
# $$i_2 = Ie^{-\frac{t}{T_2}}$$
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
#
# Q: [] Find the coupling coefficient if the Mutual inductance is 20H, the inductance of coil 1 is 2H and the inductance of coil 2 is 8H.
#
# Cr: 5
# Cw: 20
# Cw: 12
# Cw: 10
# Cw: 2
#
# E:
# $k=\frac{M}{\sqrt(L1L2)}$
#
# !equiz
# !equestion
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/ser_ind.png, width=50 frac=0.4]
#
# !bquestion
# !bquiz
#
# Q: [] Calculate the equivalent inductance between A and B in the figure above.
#
# Cw: 30 H
# Cw: 60 H
# Cr: 44 H
# Cw: 109 H
# Cw: 54 H
#
# E:
# $$L_{equ} = \sum_i L_i$$
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] A  coil,  of  inductance  5 H  and  resistance  100 Ω, carries  a  steady  current  of  2 A.  Calculate  the  initial rate of fall of current in the coil
#     after a short-circuiting switch   connected   across   its   terminals   has   been  suddenly  closed.  What  was  the  energy  stored  in  the coil?
#
# Cr: -40 A/s, 10 J
# Cw: 40 A/s, 10 J
# Cw: -20 A/s, 10 J
# Cw: 20 A/s, 10 J
# Cw: 0 A/s, 10 J
#
# E:
#
# emf estabished in the circuit due to the emf induced in the inductor
# $$e = IR$$
# The current will decrease to zero wrt time i.e. decreasing slope (-ve)
# $$e = L\frac{\mathrm{d}i}{\mathrm{d}t}$$
# Before the shorting-circuiting, the energy stored (that estabished the circuit's current and emf) is:
# $$energy = 1/2LI^2$$
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
#
# Q: [] Strictly speaking, which element in an atom is responsible for a current flow?
#
# Cw: electrons and holes
# Cw: holes
# Cr: electrons
# Cw: all of the above
# Cw: none of the above
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
#
# Q: [] Which of these is an acceptable description of an instrinsic semiconductor?
#
# Cr: A silicon waifer with less than or equal to 1 part in $10^{10}$ impurity
# Cw: A silicon waifer with more than or equal to 1 part in $10^{10}$ impurity
# Cw: A silicon waifer without any impurity
# Cw: A silicon waifer not doped with an acceptor
# Cw: A silicon waifer not doped with a donor
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
#
# Q: [] The action of applying a p.d. across metal electrodes S and T of a semiconductor device, with S being positive relative to T is known as:
#
# Cr: Forward biasing
# Cw: Reverse biasing
# Cw: Equipotential biasing
# Cw: Junction biasing
# Cw: None of the above
#
# !equiz
# !equestion
#
# !bquestion
# !bquiz
# Q: [] A piece of doped semiconductor material is introduced into  a  circuit.  If  the  temperature  of  the  material  is
# raised, will the circuit current:
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
# !equestion

# %% [markdown]
# # WorkBook

# %%
# %%activity ~/activity.do::06/27/2018 06:38PM::60
#
# !bquiz
# Q: [1] Explain the significance of the root-mean-square value
# of an alternating current or voltage waveform. Define
# the form factor of such a waveform.
# Calculate from first principles the r.m.s. value and form factor
# of an alternating  voltage having the following values over half a cycle,
# both half-cycles being symmetrical about the zero axis:
#
# |----c-------------c-------|
# |Time(ms)   | Voltage (V)  |
# |---c--------------c-------|
# | 0         |  0           |
# | 1         | 100          |
# | 2         | 100          |
# | 3         | 100          |
# | 4         |  0           |
# |--------------------------|
#
# These voltage values are joined by straight lines,
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
#
# Q: [2] Explain what is meant by the terms waveform,
# frequency and average value.
# A square coil of side 10 cm, having 100 turns, is
# rotated at 1200 r/min about an axis through the centre
# and parallel with two sides in a uniform magnetic
# field of density 0.4 T. Calculate: (a) the frequency;
# (b) the root-mean-square value of the induced e.m.f.;
# (c) the instantaneous value of the induced e.m.f. when
# the coil is at a position 40° after passing its maximum
# induced voltage.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
#
# !bquiz
# Q: [3] Derive an expression for the instantaneous value of alternating sinusoidal e.m.f. in
#     terms of its maximum value, angular freq. and time.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [4] A resultant current is made of two components : a 10 A d.c. component
#         and a sinusoidal component of maximum value 14.14 A.
#         The average value of the resultant current is?
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [5] The reactance offered by a capacitor to alternating current of
#     frequency 50 Hz is $10\Omega$. If frequency is increased to 100 Hz reactance becomes?
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [6] A circuit having a resistance of $12\Omega$, an inductance of 0.15 H and a
#     capacitance of 100$\mu F$ in series is connected across a 100V, 50Hz supply.
#     Calculate the impedance, current, the phase difference between the current
#     and supply voltage.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [7] The potential difference measured across a coil is 20 V
# when a direct current of 2 A is passed through it. With
# an alternating current of 2 A at 40 Hz, the p.d. across
# the coil is 140 V. If the coil is connected to a 230 V,
# 50 Hz supply, calculate: (a) the current; (b) the active
# power; (c) the power factor.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [8] A non-inductive resistor is connected in series with a
# coil across a 230 V, 50 Hz supply. The current is 1.8 A
# and the potential differences across the resistor and
# the coil are 80 V and 170 V respectively. Calculate the
# inductance and the resistance of the coil, and the phase
# difference between the current and the supply voltage.
# Also draw the phasor diagram representing the cur-
# rent and the voltages.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [9] A parallel network consists of two branches A and B.
# Branch A has a resistance of $10\Omega$ and an inductance
# of 0.1 H in series. Branch B has a resistance of $20\Omega$
# and a capacitance of 100 $\mu F$ in series. The network is
# connected to a single-phase supply of 230 V at 50 Hz.
# Calculate the magnitude and phase angle of the
# current taken from the supply. Verify your answers by
# measurement from a phasor diagram drawn to scale.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [10] A coil having a resistance of 20 $\Omega$ and an inductance
# of 0.15 H is connected in series with a 100 $\mu F$
# capacitor across a 230 V, 50 Hz supply. Calculate:
# (a) the active and reactive components of the current;
# (b) the voltage across the coil. Sketch the phasor
# diagram.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [11] Two circuits with impedances of $Z_1 = 10 + j15\Omega$ and $Z_2 = 6 – j8\Omega$
#     are connected in parallel. If the supply current is 20A, what is the power dissipated
#     in each branch?
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [12] The voltage applied across
# 3-branched circuit of the figure below is given by $v = 100 sin(5000t + \pi/4)$.
# Calculate the branch currents and total current
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/parallel_cct.png, width=100 frac=0.8]
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [13] The currents is each branch of a two branched parallel circuit is given as :
#
#         $$ i_a = 8.07 sin(314 t - \frac{\pi}{4})$$
#
#         $$ i_b = - 21.2 sin(314 t - \frac{\pi}{3})$$
#
#         and supply voltage is v = 354 sin 314 t.
#         Calculate :
#         (i) Total current in the same form (ii) Calculate ohmic value of components in each branch
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [14] Three impedances $z_1 = (8 + j6) \Omega$, $z_2 = (2 - j1.5) \Omega$ and $z_3 = 2 \Omega$ are connected in parallel across a
#         50Hz supply. If the current through $z_1$ is 3 + j4 amp, calculate the current through the other
#         impedances and also power absorbed by this parallel circuit.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [15] A single-phase motor takes 8.3 A at a power factor
#         of 0.866 lagging when connected to a 230 V, 50 Hz
#         supply. Two similar capacitors are connected in
#         parallel with each other to form a capacitance bank.
#         This capacitance bank is now connected in parallel
#         with the motor to raise the power factor to unity.
#         Determine the capacitance of each capacitor.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [16] A parallel network consists of two branches A and B.
#         Branch A has a resistance of $10 \Omega$ and an inductance
#         of 0.1 H in series. Branch B has a resistance of 20 $\Omega$
#         and a capacitance of $100 \mu F$ in series. The network is
#         connected to a single-phase supply of 230 V at 50 Hz.
#         Calculate the magnitude and phase angle of the
#         current taken from the supply. Verify your answers by
#         measurement from a phasor diagram drawn to scale
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [17] Resistor (= R), choke-coil (r, L), and a capacitor of $25.2 \mu F$ are connected in
#         series. When supplied from an A.C. source, in takes 0.4 A. If the voltage across the resistor is 20 V,
#         voltage across the resistor and choke is 45 volts, voltage across the choke is 35 volts, and voltage
#         across the capacitor is 50 V.
#         Find : (a) The values of r, L (b) Applied voltage and its frequency, (c) P.F. of the total circuit and
#         active power consumed. Draw the phasor diagram.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [18] Two impedances consist of (resistance of 15 ohms and series-connected induc-
#         tance of 0.04 H) and (resistance of 10 ohms, inductance of 0.1 H and a capacitance of $100 \mu F$, all in
#         series) are connectd in series and are connected to a 230 V, 50 Hz a.c. source. Find : (i) Current
#         drawn, (ii) Voltage across each impedance, (iii) Individual and total power factor. Draw the phasor
#         diagram.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [19] Define Apparant Power and Power factor in a.c. circuit. Describe parallel resonance and list its
#         important properties.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [20] A series circuit having a resistance of $10 \Omega$, and inductance of $(1/2\pi)$ H and a variable cap. is
#         connected to 100 V, 50 Hz supply. Calculate the value of capacitor to form series resonance. Calculate
#         resonant current, power and power factor.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [21] Calculate the following in polar form :
#         (i) Add (40 + j20) to (20 + j120)
#         (ii) Subtract (10 + j30) from (20 – j20)
#         (iii) Multiply (15 + j20) with (20 + j30)
#         (iv) Devide (6 + j7) by (5 + j3)
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [22] Express in rectangular form and polar form a vector, the magnitude of which is 100 units and the
#         phase of which with respect to reference axis is
#         (a) + 30° (b) + 180° (c) − 60° (d) + 120° (e) − 120° (f) − 210°.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [23] A voltage, v = 150 sin(314t + 30°) volts, is maintained
#         across a circuit consisting of a $20 \Omega$ non-reactive resis-
#         tor in series with a loss-free $100 \mu F$ capacitor. Derive
#         an expression for the r.m.s. value of the current pha-
#         sor in: (a) rectangular notation; (b) polar notation.
#         Draw the phasor diagram.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [24] The p.d. across and the current in a given circuit are
#         represented by (200 + j30) V and (5 − j2) A respect-
#         ively. Calculate the active power and the reactive
#         power. State whether the reactive power is leading or
#         lagging.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [25] A circuit consists of a $10 \Omega$ resistor, a 30 mH inductor
#         and a $1 \mu F$ capacitor, and is supplied from a 10 V
#         variable-frequency source. Find the frequency for
#         which the voltage developed across the capacitor is a
#         maximum and calculate the magnitude of this voltage.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [26] A series circuit consists of a $0.5 \mu F$ capacitor, a coil of
#         inductance 0.32 H and resistance $40 \Omega$ and a $20 \Omega$
#         non-inductive resistor. Calculate the value of the res-
#         onant frequency of the circuit. When the circuit is
#         connected to a 30 V a.c. supply at this resonant fre-
#         quency, determine: (a) the p.d. across each of the three
#         components; (b) the current flowing in the circuit;
#         (c) the active power absorbed by the circuit.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [27] What is the resonant angular frequency of an RLC circuit with $R=0.200 \Omega$, L=$4.00×10^{−3}H$, and C=$2.00×10^{−6}F$?
#         (b) If an ac source of constant amplitude 4.00 V is set to this frequency, what is the average power transferred to the circuit?
#         (c) Determine Q and the bandwidth of this circuit.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [28] The resonant angular frequency of an RLC series circuit is 4.0×102 rad/s.
#         An ac source operating at this frequency transfers an average power of $2.0×10^{−2}W$ to the circuit.
#         The resistance of the circuit is $0.50 \Omega$. Write an expression for the emf of the source.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [29] Determine the Thévenin equivalent circuit for the network shown in Figure below.
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/na_1.png, width=100 frac=0.8]
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [30] For the network shown in Figure below, determine the
#         current in $R_L$ . Use both Norton’s theorem and nodal
#         analysis.
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/na_2.png, width=100 frac=0.8]
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [31] Two circuits the impedances of which are given by $Z_1 = (10 + j 15)\Omega$
#     and $Z_2 = (6 - j 8)\Omega$ are connected in parallel. If the total current supplied is 15 A.
#     What is the power taken by each branch?
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [32] With the help of Millman’s theorem, calculate the voltage across the 1 K resistor
#     in the circuit of below.
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/na_3.png, width=100 frac=0.8]
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [33] A transformer is used to step down 230 V from a wall socket to 9.0 V for a radio.
#
# (a) If the primary winding has 500 turns, how many turns does the secondary winding have?
#
# (b) If the radio operates at a current of 500 mA, what is the current through the primary winding?
#
#
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [34] An ac source of emf delivers 5.0 mW of power at an rms current of 2.0 mA
#     when it is connected to the primary coil of a transformer.
#     The rms voltage across the secondary coil is 20 V.
#
# (a) What are the voltage across the primary coil and the current through the secondary coil?
#
# (b) What is the ratio of secondary to primary turns for the transformer?
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [35] A single-phase 50 Hz transformer has 80 turns on
#         the primary winding and 400 turns on the secondary
#         winding. The net cross-sectional area of the core is
#         $200 cm^2$ . If the primary winding is connected to a
#         230 V, 50 Hz supply, determine: (a) the e.m.f. induced
#         in the secondary winding; (b) the maximum value of
#         the flux density in the core.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [36] A 40 kV A transformer has a core loss of 450 W and a
#         full-load $I^2 R$ loss of 850 W. If the power factor of the
#         load is 0.8, calculate: (a) the full-load efficiency; (b) the
#         maximum efficiency; (c) the load at which maximum
#         efficiency occurs
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [37] A simple relay has an airgap of length 1.0 mm and
#         effective cross-sectional area 1000 $mm^2$ . The magnet-
#         izing coil consists of 1000 turns of wire carrying a
#         current of 200 mA. Calculate the energy stored in the
#         airgap. The reluctance of the ferromagnetic part of the
#         magnetic circuit may be neglected.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [38] An electromagnet is shown in Figure below to be in close
#         proximity to a bar of steel. The flux in the magnetic
#         circuit is 2.5 m Wb. Assuming that the reluctance of
#         the magnetic circuit is concentrated in the airgap and
#         that fringing is negligible, calculate the horizontal and
#         vertical forces experienced by the steel bar.
#
# FIGURE: [/home/imachine/Documents/Jupyter_projects/quizzer/images/gen_1.png, width=100 frac=0.8]
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [39] Describe how such a digital electronic voltmeter
#         could be modified to indicate currents in the range 0 to
#         100 mA.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [40] A four-digit voltmeter incorporates an A/D converter.
#         Describe its operation when measuring a voltage of
#         148.5 V.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [41] A moving-coil instrument gives full-scale deflection with 15 mA and has a resistance
#         of $5 \Omega$. Calculate the resistance of the necessary components in order
#         that the instrument may be used as: (a) a 2 A ammeter; (b) a 100 V voltmeter.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
#
# !bquiz
# Q: [42] A moving-coil instrument, used as a voltmeter, has
#         a coil of 150 turns with a width of 3 cm and an active
#         length of 3 cm. The gap flux density is 0.15 T. If the
#         full-scale reading is 150 V and the total resistance of
#         the instrument is $100000 \Omega$, find the torque exerted
#         by the control springs at full scale.
#
# Cr: increase
# Cw: remain the same
# Cw: decrease
# Cw: cease to flow
# Cw: None of the above
#
# !equiz
