# %% [markdown]
# <html>
#     <head>
#         <title>Virtual Laboratory></title>
#     </head>
#     <body>
#         <h1 style='text-align: center;'>NETWORK THEOREM</h1><br>
#         <p>In this experiment, students will investigate the following network theorems:</p>
#         <ul>
#             <li>Kirchoff's Law</li>
#             <li>Superposition theorems</li>
#             <li>Thevenin's theorem</li>
#         </ul><br>
#         <p>Students will be made to</p>
#         <p>
#         (a) explore the idea of resistance of a component<br>
#         (b) investigate the connection of resistors in series and in parallel in a circuit<br>
#         (c) determine the total current $I_{T}$ in a circuit containing resistors connected in parallel and<br>
#         (d) investigate series/parallel circuits and lines circuit Thevenin theorem.
#         </p>
#         <br>
#         <h3>Resistance of a Components</h3><br>
#         <p>Theory: Conductors that are manufactured to have particular values of resistance are called 'RESISTORS'</p><br>
#         <p>This component is used in various parts of electrical circuit to control the flow of current in that circuit.
#             Since energy is dissipated as heat in a resistor, the design of a resistor for a particular purpose must take
#             into consideration both the value of resistance and power, so that the temperature of the resistor does not
#             exceed a safe value.
#         </p><br>
#         <h4>Apparatus Required</h4><br>
#         <ul>
#         1. Digital Multi-meter<br>
#         2. Variable DC Power Supply<br>
#         3. Module, type 292A<br>
#         4. Milliameters, DC 0-1mA, 0-100mA<br>
#         5. Ammeter, d.c. 0-1A<br>
#         6. Voltmeter, d.c. 0-15V<br>
#         7. Connecting wires,<br>
#         </ul>
#         <h4>Procedure:</h4><br>
#         <p>(a) Connect up the circuit connection as shown in <b>Fig. 2.1.</b> The module equivalent circuit is as in Fig. 2.0(not shown)</p><br>
#         <p>*Now, return the power supply back to fully counterclock wise i.e. zero d.c position</p>
#     </body>
# </html>

# %%
import schemdraw as schem
import schemdraw.elements as e

d = schem.Drawing(unit=2)

V = d.add(e.MeterV, d='down', botlabel='$0-10V$')
d.add(e.LINE, d='down', l=1)

d.add(e.LINE, d='right', l=8)
d.add(e.LINE, d='right', l=2)

d.add(e.LINE, d='up', l=1)
Com1 = d.add(e.ResistorIEC, d='up', botlabel='$component_1$')
d.add(e.LINE, d='up', l=1)

d.add(e.LINE, d='left', l=2)
A = d.add(e.MeterA, d='left', botlabel='$0-1A$')
d.add(e.LINE, d='left', l=2)

d.push()
d.add(e.LINE, d='down', l=1)
S = d.add(e.Battery, d='down',toy=V.end, botlabel='$PSU$')
d.add(e.LINE, d='down', l=1)

d.pop()
d.add(e.LINE, d='left',tox=V.start, l=2)
d.add(e.LINE, d='down', l=1)



d.draw()

# %% [markdown]
# <p style="text-align:left;"><b>Figure 2.1</b></p><br>
# <p>Please, after the connection is made, <i><u>Strictly</u></i> follow the procedure that follow before switching on the power supply.<p><br>
# <ol>
#     <li>Make sure that the variable adjust control knob is <b>fully counter-clockwise,</b> and the <b>current-adjust / current limit</b> control knob <b>(if any)</b> adjusted to <b>fully-clockwise position.</b></li>
#     <li>Always allow the instructor cross-check your connections and certify them correct before switching power into your circuit</li>
#     <li>Then switch on the power supply unit. The voltage output from the power supply should read zero.</li>
#     <li>
#         Gradually increase the applied voltage in step of 1volt, between 0 and 15V (using <b>coarse</b> and <b>fine</b> adjust control knobs) of the power supply <b>(if any)</b> and at each step measure the current flowing in '1' on the module 292A</li>
#     <li>Make sure you take all the readings for <b>component 1</b> before you start procedure for <b>component 2 etc.</b>      </li>
#    <li>
#         Also, make a table of current against voltage as shown in Table 2-1. Then plot a graph of V against I. on the graph sheet provided.
#     </li>
# </ol>

# %%
from ipysheet import sheet, cell, row, column, cell_range

sheet1 = sheet(rows=11, columns=5, column_headers=False, row_headers=False)

cell1 = cell(0, 0, 'Applied Volts(V)')
cell2 = cell(0, 1, 'Comp.1')
cell3 = cell(0, 2, 'Comp.2')
cell4 = cell(0, 3, 'Comp.3')
cell5 = cell(0, 4, 'Comp.4')

cell11 = cell(1, 0, '1.0')
cell12 = cell(2, 0, '2.0')
cell13 = cell(3, 0, '3.0')
cell14 = cell(4, 0, '4.0')
cell15 = cell(5, 0, '5.0')
cell16 = cell(6, 0, '6.0')
cell17 = cell(7, 0, '7.0')
cell18 = cell(8, 0, '8.0')
cell19 = cell(9, 0, '9.0')
cell10 = cell(10, 0, '10.0')

sheet1
# Out:
# Sheet(cells=(Cell(column_end=0, column_start=0, row_end=0, row_start=0, type='text', value='Applied Volts(V)')…

# %% [markdown]
#
#
#    <p style="text-align: center"><b>Table 2-1</b></p>
#     <p>7. After the procedure for <b>component 1.</b> Turn the Power Supply Unit back to zero. Then, <b>change the range of the ammeter from 0-1A to 0-10mA or 0-100mA range</b> if necessary; this is done in order to improve the sensitivity f the meter for <b>component 2.</b>
#     </p>
#     <p> 8. Connect up <b>component 2</b> and repeat procedure (5) for this <b>component.</b> Make a table of <b>voltage</b> and <b>current</b> as before. Please take note of the unit for the current measured.</p>
#           <p>Connect up <b>component 3</b> using the same procedure and set-up with first <b>0-1mA and later 0-10mA or even 0-100mA range</b> if necessary.</p>
# <br>
# <p>Now, connect <b>component 4,</b> change the range of ammeter to <b>0 - 0.1mA</b> range. <br> Repeat the procedures as before. What do you observe and comment on your result?</p>

# %%
from IPython.display import display, Markdown, clear_output
import ipywidgets as widgets

text = widgets.Text(
       value='',
       description='Ans:', )

calendar = widgets.DatePicker(
           description='Select Date')

slider = widgets.FloatSlider(
         value=1,
         min=0,
         max=10.0,
         step=0.1,)


menu = widgets.Dropdown(
       options=['red', 'blue', 'green'],
       value='red',
       description='Color:')

checkbox = widgets.Checkbox(
           description='Check to invert',)


box = widgets.VBox([text, slider, menu, calendar, checkbox ])
text
# Out:
# Text(value='', description='Ans:')
