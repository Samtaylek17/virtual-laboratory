# %% [markdown]
# # Prelab

# %% [markdown]
# # 1) Circuit Analysis

# %% [markdown]
# ## Linearity Property

# %% [markdown]
# A linear circuit is one whose output is linearly related (or directly proportional) to its input.

# %% [markdown]
# Assume that $V_{o}$ = 1V and use linearity to calculate the actual value
# of $V_{o}$ in the circuit of Fig. 4.5

# %%
from IPython.display import display, Markdown, clear_output
import ipywidgets as widgets
import schemdraw
import schemdraw.elements as elm
import sys


def create_answer_widget(entered_value):
    correct_answer = '12V'


d = schemdraw.Drawing()
d += elm.Resistor().right().label('12Ω')
d += elm.Resistor().down().label('8Ω').label(('+', '$V_o$', '-'), loc='bottom')
d += elm.Line().left().label('Fig. 4.5', loc='bottom')
d += elm.Resistor().up().label('5Ω')
d += elm.Line().left()
d += elm.SourceV().down().reverse().label('30V')
d += elm.Line().right()
d
